# %%
print('Hello World')
# Out:
# Hello World

# %%
type(10)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %%
type("python")
# Out:
# str

# %%
a = 3
b =4
if a == b:
  print("a = b")
else:
  print('a =/ b')
# Out:
# a =/ b

# %%
for x in range(1, 10, 2):
    print(x)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
a = [2, 4, 6]
for x in a:
    print(x)
# Out:
# 2
# 4
# 6

# %%
def hello():
    print("HELLO")

hello()
# Out:
# HELLO

# %%
a = [2, 4, 6]
b = len(a)
for x in range(0, b):
    print(a[x])
# Out:
# 2
# 4
# 6

# %%
a = [1, 2, 3, 4, 5, 6, 7, 8]
a[-1]
# Out:
# 8

# %%
a[:-1]
# Out:
# [1, 2, 3, 4, 5, 6, 7]
