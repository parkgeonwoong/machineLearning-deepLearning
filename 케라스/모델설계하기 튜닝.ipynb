# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filename = '/content/drive/My Drive/Colab Notebooks/dataset/ThoraricSurgery.csv'

# %%
Data_set = np.loadtxt(filename, delimiter=",")

# %%
print(Data_set)
# Out:
# [[293.     1.     3.8  ...   0.    62.     0.  ]
#  [  1.     2.     2.88 ...   0.    60.     0.  ]
#  [  8.     2.     3.19 ...   0.    66.     1.  ]
#  ...
#  [406.     6.     5.36 ...   0.    62.     0.  ]
#  [ 25.     8.     4.32 ...   0.    58.     1.  ]
#  [447.     8.     5.2  ...   0.    49.     0.  ]]

# %%
X = Data_set[:, 0:5] # 0~16번째 학습에 필요한 데이터
Y = Data_set[:, 17] # 정답 데이터

# %%
print(type(X))
print(X.shape)
print(Y.shape)
# Out:
# <class 'numpy.ndarray'>
# (470, 5)
# (470,)

# %%
model = Sequential()
model.add(Dense(30, input_dim=5, activation='relu')) # 은닉층 Dense(노드의 갯수, 입력의 노드 갯수, 활성화함수)
model.add(Dense(30, activation='relu')) 
model.add(Dense(30, activation='relu')) 
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary() # 가중치 = 17 X 30 , 바이어스 = 30 , 출력층 = 30 바이어스 = 1
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_8 (Dense)              (None, 30)                180
# _________________________________________________________________
# dense_9 (Dense)              (None, 30)                930
# _________________________________________________________________
# dense_10 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 31
# ...
# Total params: 2,071
# Trainable params: 2,071
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']) # 손실, 최적합모델, 평가 지표

# %%
history = model.fit(X, Y, epochs=500, batch_size=10)

# %%
history.history

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'])
plt.title("Training accurarcy")
plt.xlabel("Epochs")
plt.show()

# %%
plt.plot(history.history['loss'])
plt.title('Traning loss')
plt.xlabel("Epochs")
plt.show()
