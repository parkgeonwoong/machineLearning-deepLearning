# %%
# 딥러닝 구동 케라스함수 호출
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filename = '/content/drive/My Drive/Colab Notebooks/dataset/ThoraricSurgery.csv'

# %%
Data_set = np.loadtxt(filename, delimiter=",")

# %%
print(Data_set)
# Out:
# [[293.     1.     3.8  ...   0.    62.     0.  ]
#  [  1.     2.     2.88 ...   0.    60.     0.  ]
#  [  8.     2.     3.19 ...   0.    66.     1.  ]
#  ...
#  [406.     6.     5.36 ...   0.    62.     0.  ]
#  [ 25.     8.     4.32 ...   0.    58.     1.  ]
#  [447.     8.     5.2  ...   0.    49.     0.  ]]

# %%
X = Data_set[:, 0:17] # 0~16번째 학습에 필요한 데이터 = 속성
Y = Data_set[:, 17] # 정답 데이터 = 클래스

# %%
print(type(X))
print(X.shape)
print(Y.shape)
# Out:
# <class 'numpy.ndarray'>
# (470, 17)
# (470,)

# %%
# 딥러닝 구조를 짜고 층을 설정하는 부분
model = Sequential()
model.add(Dense(30, input_dim=17, activation='relu')) # 은닉층 Dense(노드의 갯수, 입력의 노드 갯수, 활성화함수)
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary() # 가중치 = 17 X 30 , 바이어스 = 30 , 출력층 = 30 바이어스 = 1
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 30)                540
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 31
# ...
# Total params: 571
# Trainable params: 571
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy']) # 손실, 최적합모델, 평가 지표
model.fit(X, Y, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 1s 2ms/step - loss: 0.5068 - accuracy: 0.4766
# Epoch 2/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1489 - accuracy: 0.8511
# Epoch 3/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1489 - accuracy: 0.8511
# Epoch 4/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1489 - accuracy: 0.8511
# Epoch 5/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1489 - accuracy: 0.8511
# Epoch 6/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1489 - accuracy: 0.8511
# Epoch 7/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1489 - accuracy: 0.8511
# Epoch 8/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1489 - accuracy: 0.8511
# Epoch 9/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1489 - accuracy: 0.8511
# Epoch 10/100
# ...
